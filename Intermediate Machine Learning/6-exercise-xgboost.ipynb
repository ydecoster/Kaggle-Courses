# %% [markdown]
# **[Intermediate Machine Learning Home Page](https://www.kaggle.com/learn/intermediate-machine-learning)**
#
# ---

# %% [markdown]
# In this exercise, you will use your new knowledge to train a model with **gradient boosting**.
#
# # Setup
#
# The questions below will give you feedback on your work. Run the following cell to set up the feedback system.

# %%
# Set up code checking
import os
if not os.path.exists("../input/train.csv"):
    os.symlink("../input/home-data-for-ml-course/train.csv", "../input/train.csv")  
    os.symlink("../input/home-data-for-ml-course/test.csv", "../input/test.csv") 
from learntools.core import binder
binder.bind(globals())
from learntools.ml_intermediate.ex6 import *
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# You will work with the [Housing Prices Competition for Kaggle Learn Users](https://www.kaggle.com/c/home-data-for-ml-course) dataset from the previous exercise.
#
# ![Ames Housing dataset image](https://i.imgur.com/lTJVG4e.png)
#
# Run the next code cell without changes to load the training and validation sets in `X_train`, `X_valid`, `y_train`, and `y_valid`.  The test set is loaded in `X_test`.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Read the data
X = pd.read_csv('../input/train.csv', index_col='Id')
X_test_full = pd.read_csv('../input/test.csv', index_col='Id')

# Remove rows with missing target, separate target from predictors
X.dropna(axis=0, subset=['SalePrice'], inplace=True)
y = X.SalePrice              
X.drop(['SalePrice'], axis=1, inplace=True)

# Break off validation set from training data
X_train_full, X_valid_full, y_train, y_valid = train_test_split(X, y, train_size=0.8, test_size=0.2,
                                                                random_state=0)

# "Cardinality" means the number of unique values in a column
# Select categorical columns with relatively low cardinality (convenient but arbitrary)
low_cardinality_cols = [cname for cname in X_train_full.columns if X_train_full[cname].nunique() < 10 and 
                        X_train_full[cname].dtype == "object"]

# Select numeric columns
numeric_cols = [cname for cname in X_train_full.columns if X_train_full[cname].dtype in ['int64', 'float64']]

# Keep selected columns only
my_cols = low_cardinality_cols + numeric_cols
X_train = X_train_full[my_cols].copy()
X_valid = X_valid_full[my_cols].copy()
X_test = X_test_full[my_cols].copy()

# One-hot encode the data (to shorten the code, we use pandas)
X_train = pd.get_dummies(X_train)
X_valid = pd.get_dummies(X_valid)
X_test = pd.get_dummies(X_test)
X_train, X_valid = X_train.align(X_valid, join='left', axis=1)
X_train, X_test = X_train.align(X_test, join='left', axis=1)

# %% [markdown]
# # Step 1: Build model
#
# In this step, you'll build and train your first model with gradient boosting.
#
# - Begin by setting `my_model_1` to an XGBoost model.  Use the [XGBRegressor](https://xgboost.readthedocs.io/en/latest/python/python_api.html#xgboost.XGBRegressor) class, and set the random seed to 0 (`random_state=0`).  **Leave all other parameters as default.**
# - Then, fit the model to the training data in `X_train` and `y_train`.

# %%
from xgboost import XGBRegressor

# Define the model
my_model_1 = XGBRegressor(random_state=0) # Your code here

# Fit the model
my_model_1.fit(X_train, y_train) # Your code here

# Check your answer
step_1.a.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#step_1.a.hint()
#step_1.a.solution()

# %% [markdown]
# Set `predictions_1` to the model's predictions for the validation data.  Recall that the validation features are stored in `X_valid`.

# %%
from sklearn.metrics import mean_absolute_error

# Get predictions
predictions_1 = my_model_1.predict(X_valid) # Your code here

# Check your answer
step_1.b.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#step_1.b.hint()
#step_1.b.solution()

# %% [markdown]
# Finally, use the `mean_absolute_error()` function to calculate the mean absolute error (MAE) corresponding to the predictions for the validation set.  Recall that the labels for the validation data are stored in `y_valid`.

# %%
# Calculate MAE
mae_1 = mean_absolute_error(predictions_1, y_valid) # Your code here

# Uncomment to print MAE
print("Mean Absolute Error:" , mae_1)

# Check your answer
step_1.c.check()
# Out:
# Mean Absolute Error: 17662.736729452055
# Correct

# %%
# Lines below will give you a hint or solution code
#step_1.c.hint()
#step_1.c.solution()

# %% [markdown]
# # Step 2: Improve the model
#
# Now that you've trained a default model as baseline, it's time to tinker with the parameters, to see if you can get better performance!
# - Begin by setting `my_model_2` to an XGBoost model, using the [XGBRegressor](https://xgboost.readthedocs.io/en/latest/python/python_api.html#xgboost.XGBRegressor) class.  Use what you learned in the previous tutorial to figure out how to change the default parameters (like `n_estimators` and `learning_rate`) to get better results.
# - Then, fit the model to the training data in `X_train` and `y_train`.
# - Set `predictions_2` to the model's predictions for the validation data.  Recall that the validation features are stored in `X_valid`.
# - Finally, use the `mean_absolute_error()` function to calculate the mean absolute error (MAE) corresponding to the predictions on the validation set.  Recall that the labels for the validation data are stored in `y_valid`.
#
# In order for this step to be marked correct, your model in `my_model_2` must attain lower MAE than the model in `my_model_1`.

# %%
# Define the model
my_model_2 = XGBRegressor(random_state=0, n_estimators=1000, learning_rate=0.05, n_jobs=2) # Your code here

# Fit the model
my_model_2.fit(X_train, y_train, 
             early_stopping_rounds=5, 
             eval_set=[(X_train, y_train), (X_valid, y_valid)], 
             verbose=True) # Your code here

# Get predictions
predictions_2 = my_model_2.predict(X_valid) # Your code here

# Calculate MAE
mae_2 = mean_absolute_error(predictions_2, y_valid) # Your code here

# Uncomment to print MAE
print("Mean Absolute Error:" , mae_2)

# Check your answer
step_2.check()
# Out:
# [0]	validation_0-rmse:187716.59375	validation_1-rmse:190309.28125
# Multiple eval metrics have been passed: 'validation_1-rmse' will be used for early stopping.
#
# Will train until validation_1-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse:178808.98438	validation_1-rmse:181580.90625
# [2]	validation_0-rmse:170349.96875	validation_1-rmse:173377.75000
# [3]	validation_0-rmse:162316.09375	validation_1-rmse:165566.65625
# [4]	validation_0-rmse:154675.28125	validation_1-rmse:158257.42188
# [5]	validation_0-rmse:147394.96875	validation_1-rmse:151197.42188
# [6]	validation_0-rmse:140492.90625	validation_1-rmse:144560.06250
# [7]	validation_0-rmse:133918.35938	validation_1-rmse:138040.31250
# [8]	validation_0-rmse:127677.04688	validation_1-rmse:131965.81250
# [9]	validation_0-rmse:121745.69531	validation_1-rmse:126296.07031
# [10]	validation_0-rmse:116103.67188	validation_1-rmse:120776.17188
# [11]	validation_0-rmse:110742.40625	validation_1-rmse:115432.46094
# [12]	validation_0-rmse:105626.35156	validation_1-rmse:110737.27344
# [13]	validation_0-rmse:100772.23438	validation_1-rmse:106009.86719
# [14]	validation_0-rmse:96157.71094	validation_1-rmse:101745.64062
# [15]	validation_0-rmse:91784.57031	validation_1-rmse:97546.42188
# [16]	validation_0-rmse:87609.16406	validation_1-rmse:93823.48438
# [17]	validation_0-rmse:83618.60156	validation_1-rmse:90271.52344
# [18]	validation_0-rmse:79859.88281	validation_1-rmse:86875.27344
# [19]	validation_0-rmse:76270.41406	validation_1-rmse:83674.84375
# [20]	validation_0-rmse:72832.88281	validation_1-rmse:80660.32031
# [21]	validation_0-rmse:69582.82031	validation_1-rmse:77843.10938
# [22]	validation_0-rmse:66495.91406	validation_1-rmse:75228.12500
# [23]	validation_0-rmse:63565.62109	validation_1-rmse:72756.50000
# [24]	validation_0-rmse:60776.32422	validation_1-rmse:70473.10156
# [25]	validation_0-rmse:58127.82812	validation_1-rmse:68028.10156
# [26]	validation_0-rmse:55607.56250	validation_1-rmse:65990.35938
# [27]	validation_0-rmse:53207.92969	validation_1-rmse:64018.04297
# [28]	validation_0-rmse:50934.58594	validation_1-rmse:62036.74219
# [29]	validation_0-rmse:48753.64844	validation_1-rmse:60086.34375
# [30]	validation_0-rmse:46696.23047	validation_1-rmse:58495.95703
# [31]	validation_0-rmse:44741.68359	validation_1-rmse:56855.01172
# [32]	validation_0-rmse:42884.19531	validation_1-rmse:55310.39844
# [33]	validation_0-rmse:41099.41406	validation_1-rmse:53747.23828
# [34]	validation_0-rmse:39393.21484	validation_1-rmse:52577.71875
# [35]	validation_0-rmse:37787.21875	validation_1-rmse:51164.88672
# [36]	validation_0-rmse:36254.37500	validation_1-rmse:50135.95312
# [37]	validation_0-rmse:34816.69141	validation_1-rmse:49052.98438
# [38]	validation_0-rmse:33443.65625	validation_1-rmse:48172.56641
# [39]	validation_0-rmse:32142.81250	validation_1-rmse:47233.09375
# [40]	validation_0-rmse:30901.72070	validation_1-rmse:46413.98828
# [41]	validation_0-rmse:29723.33984	validation_1-rmse:45715.58984
# [42]	validation_0-rmse:28605.38477	validation_1-rmse:45075.17188
# [43]	validation_0-rmse:27559.08789	validation_1-rmse:44368.63281
# [44]	validation_0-rmse:26549.81836	validation_1-rmse:43740.31250
# [45]	validation_0-rmse:25598.61914	validation_1-rmse:43198.72656
# [46]	validation_0-rmse:24692.11328	validation_1-rmse:42687.54297
# [47]	validation_0-rmse:23833.76758	validation_1-rmse:42165.46875
# [48]	validation_0-rmse:23011.40234	validation_1-rmse:41742.30078
# [49]	validation_0-rmse:22227.09961	validation_1-rmse:41314.53125
# [50]	validation_0-rmse:21479.01562	validation_1-rmse:40912.02344
# [51]	validation_0-rmse:20763.01953	validation_1-rmse:40578.46094
# [52]	validation_0-rmse:20079.12695	validation_1-rmse:40135.35938
# [53]	validation_0-rmse:19417.63672	validation_1-rmse:39812.58984
# [54]	validation_0-rmse:18809.79102	validation_1-rmse:39552.57031
# [55]	validation_0-rmse:18225.78125	validation_1-rmse:39151.50391
# [56]	validation_0-rmse:17684.31055	validation_1-rmse:38884.49609
# [57]	validation_0-rmse:17154.99609	validation_1-rmse:38517.07422
# [58]	validation_0-rmse:16651.37891	validation_1-rmse:38220.00000
# [59]	validation_0-rmse:16186.81543	validation_1-rmse:38030.26953
# [60]	validation_0-rmse:15743.42969	validation_1-rmse:37749.97656
# [61]	validation_0-rmse:15324.26367	validation_1-rmse:37582.36719
# [62]	validation_0-rmse:14930.51953	validation_1-rmse:37383.67969
# [63]	validation_0-rmse:14556.76367	validation_1-rmse:37241.63281
# [64]	validation_0-rmse:14196.60156	validation_1-rmse:37057.30078
# [65]	validation_0-rmse:13846.22266	validation_1-rmse:36952.49609
# [66]	validation_0-rmse:13525.88574	validation_1-rmse:36783.47266
# [67]	validation_0-rmse:13206.15137	validation_1-rmse:36672.97266
# [68]	validation_0-rmse:12914.48731	validation_1-rmse:36564.72656
# [69]	validation_0-rmse:12647.87598	validation_1-rmse:36382.50391
# [70]	validation_0-rmse:12367.39160	validation_1-rmse:36297.64062
# [71]	validation_0-rmse:12120.34961	validation_1-rmse:36132.00391
# [72]	validation_0-rmse:11891.10254	validation_1-rmse:36059.39453
# [73]	validation_0-rmse:11686.92676	validation_1-rmse:35906.76562
# [74]	validation_0-rmse:11488.30078	validation_1-rmse:35765.69141
# [75]	validation_0-rmse:11281.55176	validation_1-rmse:35693.17578
# [76]	validation_0-rmse:11104.23731	validation_1-rmse:35558.73047
# [77]	validation_0-rmse:10919.22168	validation_1-rmse:35447.77734
# [78]	validation_0-rmse:10735.94434	validation_1-rmse:35320.83203
# [79]	validation_0-rmse:10589.25391	validation_1-rmse:35220.38281
# [80]	validation_0-rmse:10439.75586	validation_1-rmse:35108.00391
# [81]	validation_0-rmse:10289.49219	validation_1-rmse:35020.15625
# [82]	validation_0-rmse:10142.30762	validation_1-rmse:34905.44531
# [83]	validation_0-rmse:10016.34375	validation_1-rmse:34807.67969
# [84]	validation_0-rmse:9885.23633	validation_1-rmse:34706.99609
# [85]	validation_0-rmse:9771.48633	validation_1-rmse:34605.14062
# [86]	validation_0-rmse:9668.79102	validation_1-rmse:34575.68750
# [87]	validation_0-rmse:9565.86133	validation_1-rmse:34502.43750
# [88]	validation_0-rmse:9474.34082	validation_1-rmse:34475.05078
# [89]	validation_0-rmse:9371.06836	validation_1-rmse:34390.65625
# [90]	validation_0-rmse:9279.60352	validation_1-rmse:34301.41016
# [91]	validation_0-rmse:9187.11133	validation_1-rmse:34214.35547
# [92]	validation_0-rmse:9098.58789	validation_1-rmse:34220.12500
# [93]	validation_0-rmse:9013.18945	validation_1-rmse:34132.69922
# [94]	validation_0-rmse:8931.15625	validation_1-rmse:34147.07812
# [95]	validation_0-rmse:8860.16504	validation_1-rmse:34129.37109
# [96]	validation_0-rmse:8786.95898	validation_1-rmse:34048.60938
# [97]	validation_0-rmse:8715.92481	validation_1-rmse:34036.41016
# [98]	validation_0-rmse:8647.60449	validation_1-rmse:33961.56641
# [99]	validation_0-rmse:8584.53711	validation_1-rmse:33945.41406
# [100]	validation_0-rmse:8521.76367	validation_1-rmse:33881.33203
# [101]	validation_0-rmse:8445.23926	validation_1-rmse:33819.76172
# [102]	validation_0-rmse:8391.26953	validation_1-rmse:33762.46875
# [103]	validation_0-rmse:8332.65527	validation_1-rmse:33687.84766
# [104]	validation_0-rmse:8273.42773	validation_1-rmse:33657.92578
# [105]	validation_0-rmse:8220.64258	validation_1-rmse:33604.57031
# [106]	validation_0-rmse:8176.27490	validation_1-rmse:33562.46875
# [107]	validation_0-rmse:8118.66992	validation_1-rmse:33504.75391
# [108]	validation_0-rmse:8062.04004	validation_1-rmse:33482.03516
# [109]	validation_0-rmse:8019.36523	validation_1-rmse:33437.53516
# [110]	validation_0-rmse:7988.64990	validation_1-rmse:33431.07422
# [111]	validation_0-rmse:7953.74268	validation_1-rmse:33394.17578
# [112]	validation_0-rmse:7900.94336	validation_1-rmse:33346.67578
# [113]	validation_0-rmse:7859.48682	validation_1-rmse:33309.74219
# [114]	validation_0-rmse:7829.97217	validation_1-rmse:33295.42188
# [115]	validation_0-rmse:7797.04248	validation_1-rmse:33280.08984
# [116]	validation_0-rmse:7752.41357	validation_1-rmse:33275.77344
# [117]	validation_0-rmse:7706.62793	validation_1-rmse:33267.42188
# [118]	validation_0-rmse:7671.81299	validation_1-rmse:33262.13672
# [119]	validation_0-rmse:7645.03125	validation_1-rmse:33246.12109
# [120]	validation_0-rmse:7606.32666	validation_1-rmse:33241.26172
# [121]	validation_0-rmse:7573.43555	validation_1-rmse:33215.92188
# [122]	validation_0-rmse:7549.90478	validation_1-rmse:33218.37109
# [123]	validation_0-rmse:7524.75000	validation_1-rmse:33201.57031
# [124]	validation_0-rmse:7499.18701	validation_1-rmse:33166.91797
# [125]	validation_0-rmse:7465.21045	validation_1-rmse:33170.74609
# [126]	validation_0-rmse:7429.89551	validation_1-rmse:33189.56250
# [127]	validation_0-rmse:7380.18848	validation_1-rmse:33158.85156
# [128]	validation_0-rmse:7354.85596	validation_1-rmse:33127.34375
# [129]	validation_0-rmse:7314.76367	validation_1-rmse:33127.54688
# [130]	validation_0-rmse:7276.05518	validation_1-rmse:33114.08984
# [131]	validation_0-rmse:7255.26709	validation_1-rmse:33089.90625
# [132]	validation_0-rmse:7238.94141	validation_1-rmse:33072.12500
# [133]	validation_0-rmse:7211.40430	validation_1-rmse:33051.03906
# [134]	validation_0-rmse:7190.78955	validation_1-rmse:33027.88281
# [135]	validation_0-rmse:7161.54004	validation_1-rmse:33018.89062
# [136]	validation_0-rmse:7133.59277	validation_1-rmse:33013.18359
# [137]	validation_0-rmse:7106.44629	validation_1-rmse:33019.77344
# [138]	validation_0-rmse:7077.66553	validation_1-rmse:33015.83984
# [139]	validation_0-rmse:7060.06348	validation_1-rmse:32999.12109
# [140]	validation_0-rmse:7036.47900	validation_1-rmse:32994.00000
# [141]	validation_0-rmse:7003.96094	validation_1-rmse:32963.94141
# [142]	validation_0-rmse:6985.11426	validation_1-rmse:32960.81641
# [143]	validation_0-rmse:6968.92871	validation_1-rmse:32961.35156
# [144]	validation_0-rmse:6949.94629	validation_1-rmse:32965.43359
# [145]	validation_0-rmse:6891.15918	validation_1-rmse:32944.40625
# [146]	validation_0-rmse:6874.57275	validation_1-rmse:32941.66797
# [147]	validation_0-rmse:6831.54199	validation_1-rmse:32921.95703
# [148]	validation_0-rmse:6813.96875	validation_1-rmse:32912.16016
# [149]	validation_0-rmse:6791.46826	validation_1-rmse:32909.01562
# [150]	validation_0-rmse:6770.66748	validation_1-rmse:32896.80078
# [151]	validation_0-rmse:6737.58594	validation_1-rmse:32887.89844
# [152]	validation_0-rmse:6722.90820	validation_1-rmse:32881.08594
# [153]	validation_0-rmse:6696.09814	validation_1-rmse:32884.93750
# [154]	validation_0-rmse:6654.74805	validation_1-rmse:32866.45703
# [155]	validation_0-rmse:6636.47900	validation_1-rmse:32857.57422
# [156]	validation_0-rmse:6614.48438	validation_1-rmse:32853.70703
# [157]	validation_0-rmse:6596.48926	validation_1-rmse:32848.78516
# [158]	validation_0-rmse:6579.47217	validation_1-rmse:32837.70703
# [159]	validation_0-rmse:6556.25977	validation_1-rmse:32835.89844
# [160]	validation_0-rmse:6540.93945	validation_1-rmse:32826.76172
# [161]	validation_0-rmse:6499.49170	validation_1-rmse:32799.82422
# [162]	validation_0-rmse:6451.98340	validation_1-rmse:32790.89062
# [163]	validation_0-rmse:6407.71094	validation_1-rmse:32773.93359
# [164]	validation_0-rmse:6378.88623	validation_1-rmse:32767.15625
# [165]	validation_0-rmse:6358.43701	validation_1-rmse:32760.91797
# [166]	validation_0-rmse:6340.31494	validation_1-rmse:32761.60352
# [167]	validation_0-rmse:6311.08594	validation_1-rmse:32750.71875
# [168]	validation_0-rmse:6285.88818	validation_1-rmse:32750.55469
# [169]	validation_0-rmse:6264.07227	validation_1-rmse:32734.04688
# [170]	validation_0-rmse:6252.17188	validation_1-rmse:32734.27539
# [171]	validation_0-rmse:6225.50391	validation_1-rmse:32728.68555
# [172]	validation_0-rmse:6194.11865	validation_1-rmse:32717.91016
# [173]	validation_0-rmse:6183.57227	validation_1-rmse:32718.58984
# [174]	validation_0-rmse:6142.25781	validation_1-rmse:32709.81641
# [175]	validation_0-rmse:6113.81494	validation_1-rmse:32689.43164
# [176]	validation_0-rmse:6091.34424	validation_1-rmse:32674.01562
# [177]	validation_0-rmse:6054.02978	validation_1-rmse:32662.63477
# [178]	validation_0-rmse:6034.27100	validation_1-rmse:32656.54102
# [179]	validation_0-rmse:6020.67480	validation_1-rmse:32645.64648
# [180]	validation_0-rmse:5981.76221	validation_1-rmse:32638.09766
# [181]	validation_0-rmse:5948.95068	validation_1-rmse:32630.00781
# [182]	validation_0-rmse:5929.53125	validation_1-rmse:32629.16016
# [183]	validation_0-rmse:5915.52051	validation_1-rmse:32619.08203
# [184]	validation_0-rmse:5874.60205	validation_1-rmse:32608.64062
# [185]	validation_0-rmse:5848.18311	validation_1-rmse:32602.22852
# [186]	validation_0-rmse:5836.27051	validation_1-rmse:32592.41016
# [187]	validation_0-rmse:5821.19873	validation_1-rmse:32585.49023
# [188]	validation_0-rmse:5793.62109	validation_1-rmse:32588.74414
# [189]	validation_0-rmse:5784.82422	validation_1-rmse:32580.71875
# [190]	validation_0-rmse:5749.57422	validation_1-rmse:32583.21484
# [191]	validation_0-rmse:5733.71973	validation_1-rmse:32583.54492
# [192]	validation_0-rmse:5708.70166	validation_1-rmse:32584.53906
# [193]	validation_0-rmse:5681.48975	validation_1-rmse:32582.28906
# [194]	validation_0-rmse:5670.65869	validation_1-rmse:32571.69336
# [195]	validation_0-rmse:5632.41699	validation_1-rmse:32561.22461
# [196]	validation_0-rmse:5613.54639	validation_1-rmse:32559.17578
# [197]	validation_0-rmse:5594.92432	validation_1-rmse:32554.32812
# [198]	validation_0-rmse:5581.09033	validation_1-rmse:32552.83984
# [199]	validation_0-rmse:5558.45312	validation_1-rmse:32548.28125
# [200]	validation_0-rmse:5521.51514	validation_1-rmse:32552.05664
# [201]	validation_0-rmse:5507.19922	validation_1-rmse:32552.92969
# [202]	validation_0-rmse:5485.11523	validation_1-rmse:32551.40430
# [203]	validation_0-rmse:5464.62988	validation_1-rmse:32546.49805
# [204]	validation_0-rmse:5450.66699	validation_1-rmse:32541.10156
# [205]	validation_0-rmse:5439.15234	validation_1-rmse:32539.37891
# [206]	validation_0-rmse:5419.74707	validation_1-rmse:32539.01953
# [207]	validation_0-rmse:5402.90869	validation_1-rmse:32538.48438
# [208]	validation_0-rmse:5392.77637	validation_1-rmse:32541.25586
# [209]	validation_0-rmse:5376.35596	validation_1-rmse:32540.94531
# [210]	validation_0-rmse:5359.05957	validation_1-rmse:32536.01172
# [211]	validation_0-rmse:5340.01172	validation_1-rmse:32539.01562
# [212]	validation_0-rmse:5330.29297	validation_1-rmse:32537.41016
# [213]	validation_0-rmse:5309.51367	validation_1-rmse:32536.12695
# [214]	validation_0-rmse:5297.95361	validation_1-rmse:32531.56055
# [215]	validation_0-rmse:5267.15430	validation_1-rmse:32528.05664
# [216]	validation_0-rmse:5254.13916	validation_1-rmse:32530.81250
# [217]	validation_0-rmse:5247.37744	validation_1-rmse:32528.21289
# [218]	validation_0-rmse:5232.58398	validation_1-rmse:32532.52930
# [219]	validation_0-rmse:5218.85645	validation_1-rmse:32530.52734
# [220]	validation_0-rmse:5199.85107	validation_1-rmse:32528.23828
# Stopping. Best iteration:
# [215]	validation_0-rmse:5267.15430	validation_1-rmse:32528.05664
#
# Mean Absolute Error: 16802.965325342466
# Correct

# %%
# Lines below will give you a hint or solution code
#step_2.hint()
#step_2.solution()

# %% [markdown]
# # Step 3: Break the model
#
# In this step, you will create a model that performs worse than the original model in Step 1.  This will help you to develop your intuition for how to set parameters.  You might even find that you accidentally get better performance, which is ultimately a nice problem to have and a valuable learning experience!
# - Begin by setting `my_model_3` to an XGBoost model, using the [XGBRegressor](https://xgboost.readthedocs.io/en/latest/python/python_api.html#xgboost.XGBRegressor) class.  Use what you learned in the previous tutorial to figure out how to change the default parameters (like `n_estimators` and `learning_rate`) to design a model to get high MAE.
# - Then, fit the model to the training data in `X_train` and `y_train`.
# - Set `predictions_3` to the model's predictions for the validation data.  Recall that the validation features are stored in `X_valid`.
# - Finally, use the `mean_absolute_error()` function to calculate the mean absolute error (MAE) corresponding to the predictions on the validation set.  Recall that the labels for the validation data are stored in `y_valid`.
#
# In order for this step to be marked correct, your model in `my_model_3` must attain higher MAE than the model in `my_model_1`.

# %%
#We can do either underfitting (setting n_estimators = 1) or overfitting (which we are doing below)

# Define the model
my_model_3 = XGBRegressor(random_state=0, n_estimators=2000, learning_rate=0.4, n_jobs=2)

# Fit the model
my_model_3.fit(X_train, y_train, 
             early_stopping_rounds=5, 
             eval_set=[(X_train, y_train)], 
             verbose=True) # Your code here

# Get predictions
predictions_3 = my_model_3.predict(X_valid)

# Calculate MAE
mae_3 = mean_absolute_error(predictions_3, y_valid)

# Uncomment to print MAE
print("Mean Absolute Error:" , mae_3)

# Check your answer
step_3.check()
# Out:
# [0]	validation_0-rmse:122705.32031
# Will train until validation_0-rmse hasn't improved in 5 rounds.
# [1]	validation_0-rmse
# [251]	validation_0-rmse:9.71788
# [252]	validation_0-rmse:9.57087
# [253]	validation_0-rmse:9.41100
# [254]	validation_0-rmse:8.67792
# [255]	validation_0-rmse:8.62454
# [256]	validation_0-rmse:8.50705
# [257]	validation_0-rmse:8.38718
# [258]	validation_0-rmse:8.03867
# [259]	validation_0-rmse:7.98417
# [260]	validation_0-rmse:7.68505
# [261]	validation_0-rmse:7.45198
# [262]	validation_0-rmse:7.39841
# [263]	validation_0-rmse:7.23924
# [264]	validation_0-rmse:7.15046
# [265]	validation_0-rmse:7.03470
# [266]	validation_0-rmse:6.78274
# [267]	validation_0-rmse:6.63554
# [268]	validation_0-rmse:6.46519
# [269]	validation_0-rmse:6.40062
# [270]	validation_0-rmse:6.27076
# [271]	validation_0-rmse:5.91981
# [272]	validation_0-rmse:5.71396
# [273]	validation_0-rmse:5.62298
# [274]	validation_0-rmse:5.39136
# [275]	validation_0-rmse:5.32622
# [276]	validation_0-rmse:5.13955
# [277]	validation_0-rmse:5.07645
# [278]	validation_0-rmse:4.95798
# [279]	validation_0-rmse:4.81961
# [280]	validation_0-rmse:4.72565
# [281]	validation_0-rmse:4.57416
# [282]	validation_0-rmse:4.53256
# [283]	validation_0-rmse:4.38046
# [284]	validation_0-rmse:4.28909
# [285]	validation_0-rmse:4.25589
# [286]	validation_0-rmse:4.10629
# [287]	validation_0-rmse:3.96252
# [288]	validation_0-rmse:3.79065
# [289]	validation_0-rmse:3.65659
# [290]	validation_0-rmse:3.59039
# [291]	validation_0-rmse:3.51707
# [292]	validation_0-rmse:3.45060
# [293]	validation_0-rmse:3.38499
# [294]	validation_0-rmse:3.30245
# [295]	validation_0-rmse:3.26629
# [296]	validation_0-rmse:3.17177
# [297]	validation_0-rmse:3.10814
# [298]	validation_0-rmse:3.05629
# [299]	validation_0-rmse:2.96947
# [300]	validation_0-rmse:2.75278
# [301]	validation_0-rmse:2.66088
# [302]	validation_0-rmse:2.60670
# [303]	validation_0-rmse:2.58605
# [304]	validation_0-rmse:2.47741
# [305]	validation_0-rmse:2.41185
# [306]	validation_0-rmse:2.37730
# [307]	validation_0-rmse:2.32922
# [308]	validation_0-rmse:2.26421
# [309]	validation_0-rmse:2.21365
# [310]	validation_0-rmse:2.15018
# [311]	validation_0-rmse:2.07733
# [312]	validation_0-rmse:2.01874
# [313]	validation_0-rmse:1.97105
# [314]	validation_0-rmse:1.93068
# [315]	validation_0-rmse:1.85298
# [316]	validation_0-rmse:1.76220
# [317]	validation_0-rmse:1.74803
# [318]	validation_0-rmse:1.71833
# [319]	validation_0-rmse:1.67908
# [320]	validation_0-rmse:1.62919
# [321]	validation_0-rmse:1.56226
# [322]	validation_0-rmse:1.51170
# [323]	validation_0-rmse:1.48468
# [324]	validation_0-rmse:1.39006
# [325]	validation_0-rmse:1.33858
# [326]	validation_0-rmse:1.31643
# [327]	validation_0-rmse:1.27603
# [328]	validation_0-rmse:1.22539
# [329]	validation_0-rmse:1.20377
# [330]	validation_0-rmse:1.17032
# [331]	validation_0-rmse:1.13077
# [332]	validation_0-rmse:1.11579
# [333]	validation_0-rmse:1.10435
# [334]	validation_0-rmse:1.07442
# [335]	validation_0-rmse:1.06486
# [336]	validation_0-rmse:1.02796
# [337]	validation_0-rmse:0.99090
# [338]	validation_0-rmse:0.96472
# [339]	validation_0-rmse:0.92844
# [340]	validation_0-rmse:0.92500
# [341]	validation_0-rmse:0.91889
# [342]	validation_0-rmse:0.90060
# [343]	validation_0-rmse:0.86735
# [344]	validation_0-rmse:0.84442
# [345]	validation_0-rmse:0.81944
# [346]	validation_0-rmse:0.80203
# [347]	validation_0-rmse:0.78630
# [348]	validation_0-rmse:0.75878
# [349]	validation_0-rmse:0.74813
# [350]	validation_0-rmse:0.70955
# [351]	validation_0-rmse:0.69480
# [352]	validation_0-rmse:0.69014
# [353]	validation_0-rmse:0.68737
# [354]	validation_0-rmse:0.67783
# [355]	validation_0-rmse:0.67005
# [356]	validation_0-rmse:0.63995
# [357]	validation_0-rmse:0.63382
# [358]	validation_0-rmse:0.60537
# [359]	validation_0-rmse:0.58434
# [360]	validation_0-rmse:0.56545
# [361]	validation_0-rmse:0.54814
# [362]	validation_0-rmse:0.53473
# [363]	validation_0-rmse:0.51907
# [364]	validation_0-rmse:0.50622
# [365]	validation_0-rmse:0.49123
# [366]	validation_0-rmse:0.47709
# [367]	validation_0-rmse:0.46232
# [368]	validation_0-rmse:0.45201
# [369]	validation_0-rmse:0.44382
# [370]	validation_0-rmse:0.42894
# [371]	validation_0-rmse:0.42620
# [372]	validation_0-rmse:0.42184
# [373]	validation_0-rmse:0.40829
# [374]	validation_0-rmse:0.40066
# [375]	validation_0-rmse:0.39136
# [376]	validation_0-rmse:0.38748
# [377]	validation_0-rmse:0.38311
# [378]	validation_0-rmse:0.37348
# [379]	validation_0-rmse:0.35925
# [380]	validation_0-rmse:0.33015
# [381]	validation_0-rmse:0.32533
# [382]	validation_0-rmse:0.30557
# [383]	validation_0-rmse:0.30038
# [384]	validation_0-rmse:0.28112
# [385]	validation_0-rmse:0.26924
# [386]	validation_0-rmse:0.26760
# [387]	validation_0-rmse:0.26228
# [388]	validation_0-rmse:0.25676
# [389]	validation_0-rmse:0.24873
# [390]	validation_0-rmse:0.23756
# [391]	validation_0-rmse:0.22656
# [392]	validation_0-rmse:0.22245
# [393]	validation_0-rmse:0.21973
# [394]	validation_0-rmse:0.21828
# [395]	validation_0-rmse:0.21484
# [396]	validation_0-rmse:0.20280
# [397]	validation_0-rmse:0.19959
# [398]	validation_0-rmse:0.19376
# [399]	validation_0-rmse:0.18647
# [400]	validation_0-rmse:0.18029
# [401]	validation_0-rmse:0.17699
# [402]	validation_0-rmse:0.17390
# [403]	validation_0-rmse:0.16581
# [404]	validation_0-rmse:0.16062
# [405]	validation_0-rmse:0.15449
# [406]	validation_0-rmse:0.15115
# [407]	validation_0-rmse:0.14865
# [408]	validation_0-rmse:0.14563
# [409]	validation_0-rmse:0.14277
# [410]	validation_0-rmse:0.13831
# [411]	validation_0-rmse:0.13624
# [412]	validation_0-rmse:0.13406
# [413]	validation_0-rmse:0.12853
# [414]	validation_0-rmse:0.12252
# [415]	validation_0-rmse:0.12178
# [416]	validation_0-rmse:0.11584
# [417]	validation_0-rmse:0.11335
# [418]	validation_0-rmse:0.11029
# [419]	validation_0-rmse:0.10533
# [420]	validation_0-rmse:0.10377
# [421]	validation_0-rmse:0.09705
# [422]	validation_0-rmse:0.09310
# [423]	validation_0-rmse:0.09115
# [424]	validation_0-rmse:0.08973
# [425]	validation_0-rmse:0.08792
# [426]	validation_0-rmse:0.08443
# [427]	validation_0-rmse:0.08354
# [428]	validation_0-rmse:0.08165
# [429]	validation_0-rmse:0.07985
# [430]	validation_0-rmse:0.07884
# [431]	validation_0-rmse:0.07799
# [432]	validation_0-rmse:0.07719
# [433]	validation_0-rmse:0.07649
# [434]	validation_0-rmse:0.07557
# [435]	validation_0-rmse:0.07321
# [436]	validation_0-rmse:0.07077
# [437]	validation_0-rmse:0.06927
# [438]	validation_0-rmse:0.06725
# [439]	validation_0-rmse:0.06492
# [440]	validation_0-rmse:0.06460
# [441]	validation_0-rmse:0.06449
# [442]	validation_0-rmse:0.06376
# [443]	validation_0-rmse:0.05906
# [444]	validation_0-rmse:0.05657
# [445]	validation_0-rmse:0.05332
# [446]	validation_0-rmse:0.05277
# [447]	validation_0-rmse:0.05174
# [448]	validation_0-rmse:0.05124
# [449]	validation_0-rmse:0.05071
# [450]	validation_0-rmse:0.05028
# [451]	validation_0-rmse:0.04909
# [452]	validation_0-rmse:0.04832
# [453]	validation_0-rmse:0.04639
# [454]	validation_0-rmse:0.04580
# [455]	validation_0-rmse:0.04456
# [456]	validation_0-rmse:0.04398
# [457]	validation_0-rmse:0.04370
# [458]	validation_0-rmse:0.04360
# [459]	validation_0-rmse:0.04346
# [460]	validation_0-rmse:0.04339
# [461]	validation_0-rmse:0.04326
# [462]	validation_0-rmse:0.04282
# [463]	validation_0-rmse:0.04262
# [464]	validation_0-rmse:0.04246
# [465]	validation_0-rmse:0.04219
# [466]	validation_0-rmse:0.04192
# [467]	validation_0-rmse:0.04183
# [468]	validation_0-rmse:0.04162
# [469]	validation_0-rmse:0.04124
# [470]	validation_0-rmse:0.04088
# [471]	validation_0-rmse:0.04051
# [472]	validation_0-rmse:0.04050
# [473]	validation_0-rmse:0.04018
# [474]	validation_0-rmse:0.03982
# [475]	validation_0-rmse:0.03949
# [476]	validation_0-rmse:0.03947
# [477]	validation_0-rmse:0.03947
# [478]	validation_0-rmse:0.03944
# [479]	validation_0-rmse:0.03942
# [480]	validation_0-rmse:0.03938
# [481]	validation_0-rmse:0.03938
# [482]	validation_0-rmse:0.03939
# [483]	validation_0-rmse:0.03939
# [484]	validation_0-rmse:0.03940
# [485]	validation_0-rmse:0.03940
# Stopping. Best iteration:
# [480]	validation_0-rmse:0.03938
#
# Mean Absolute Error: 19316.418303189213
# Correct

# %%
# Lines below will give you a hint or solution code
#step_3.hint()
#step_3.solution()

# %% [markdown]
# # Keep going
#
# Continue to learn about **[data leakage](https://www.kaggle.com/alexisbcook/data-leakage)**.  This is an important issue for a data scientist to understand, and it has the potential to ruin your models in subtle and dangerous ways!

# %% [markdown]
# ---
# **[Intermediate Machine Learning Home Page](https://www.kaggle.com/learn/intermediate-machine-learning)**
#
#
#
#
#
# *Have questions or comments? Visit the [Learn Discussion forum](https://www.kaggle.com/learn-forum/161289) to chat with other Learners.*
